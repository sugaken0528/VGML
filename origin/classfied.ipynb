# %%
from google.colab import drive
drive.mount('/content/gdrive')
import sys
sys.path.append("/content/gdrive/My Drive/Colab Notebooks")
import csv
#gdrivdの同期

import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/load.txt")

docs1=np.array([])
for x in df.values:
  docs1=np.append(docs1,x)

# %%
docs=np.array([])
for x in df.values:
  if (any(map(str.isdigit, x[0]))):
    docs=np.append(docs,x)

# %%
vectorizer = TfidfVectorizer(use_idf=True,token_pattern=u'(?u)\\b\\w+\\b')
vecs = vectorizer.fit_transform(docs1)
TF_list=vecs.toarray()

words = vectorizer.get_feature_names()

doc_list=[]
for doc_id, vec in zip(range(len(docs)), vecs.toarray()):
    docs=[]
    count=0
    for w_id, tfidf in sorted(enumerate(vec), key=lambda x: x[1], reverse=True):
        lemma = words[w_id]
        if tfidf > 0.00:
          doc=[lemma,tfidf]
          docs.append(doc)
          count=count+1
    doc=[doc_id,count]
    docs.insert(0,doc)
    doc_list.append(docs)

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

# vectorizeする
vectorizer.fit(docs1)

#抽出した単語を確認する
wlist1=vectorizer.get_feature_names()
# ['a', 'am', 'and', 'are', 'i', 'man', 'perfect', 'regend', robot', 'sam', 'you']
#単語のリスト化

countlist = [0] * len(wlist1)

# %%
import pandas as pd
import numpy as np

result = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/Results dataset.csv")
result
# Out:
#          単語  判定結果   TF-IDF値  ...  連結回数  Scored Labels  Scored Probabilities
# 0        黒線     0  0.258534  ...     1              0              0.356812
# 1        黒線     0  0.247792  ...     1              0              0.356812
# 2     黒ブロック     0  0.373786  ...    13              1              0.625437
# 3     黒ブロック     0  0.256850  ...    13              1              0.625437
# 4     黒ブロック     0  0.240744  ...    13              1              0.625437
# ...     ...   ...       ...  ...   ...            ...                   ...
# 1165     0版     0  0.221862  ...     0              0              0.320266
# 1166     0版     0  0.083689  ...     0              0              0.320266
# 1167      0     0  0.327234  ...    31              1              0.610154
# 1168      0     0  0.221862  ...    31              1              0.610154
# 1169      0     0  0.083689  ...    31              1              0.610154
#
# [1170 rows x 8 columns]

# %%
#Scored Labelsが1の場合の抽出

classifier_list=[]
for x in result.values:
  if x[6]:
    list_=[]
    list_.append("INDEX_ID")    
    list_.append(x[0])
    classifier_list.append(list_)

classifier_list
# Out:
# [['INDEX_ID', '黒ブロック'],
#  ['INDEX_ID', '黒ブロック'],
#  ['INDEX_ID', '黒ブロック'],
#  ['INDEX_ID', '黒ブロック'],
#  ['INDEX_ID', '黒'],
#  ['INDEX_ID', '黒'],
#  ['INDEX_ID', '関連ファイル'],
#  ['INDEX_ID', '進入以降具体的'],
#  ['INDEX_ID', '走行体全体'],
#  ['INDEX_ID', '走行体全体'],
#  ['INDEX_ID', '走行体全体'],
#  ['INDEX_ID', '走行体全体'],
#  ['INDEX_ID', '走行体ソフトウェア'],
#  ['INDEX_ID', '走行体ソフトウェア'],
#  ['INDEX_ID', '走行体ソフトウェア'],
#  ['INDEX_ID', '走行体ソフトウェア'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行タイム'],
#  ['INDEX_ID', '走行タイム'],
#  ['INDEX_ID', '走行タイム'],
#  ['INDEX_ID', '走行タイム'],
#  ['INDEX_ID', '走行'],
#  ['INDEX_ID', '走行'],
#  ['INDEX_ID', '走行'],
#  ['INDEX_ID', '走行'],
#  ['INDEX_ID', '走行'],
#  ['INDEX_ID', '設置プライマリークラス難所'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '計測終了操作'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '灰色点線内'],
#  ['INDEX_ID', '灰色点線内'],
#  ['INDEX_ID', '最大計測時間'],
#  ['INDEX_ID', '最大計測時間'],
#  ['INDEX_ID', '最大計測時間'],
#  ['INDEX_ID', '時間計測'],
#  ['INDEX_ID', '時間計測'],
#  ['INDEX_ID', '時間計測'],
#  ['INDEX_ID', '数字カード黒ブロック全体'],
#  ['INDEX_ID', '数字カード黒ブロック'],
#  ['INDEX_ID', '数字カード黒ブロック'],
#  ['INDEX_ID', '数字カード黒ブロック'],
#  ['INDEX_ID', '数字カード黒ブロック'],
#  ['INDEX_ID', '数字カード置き場'],
#  ['INDEX_ID', '数字カード置き場'],
#  ['INDEX_ID', '数字カード置き場'],
#  ['INDEX_ID', '数字カードボーナスサークル'],
#  ['INDEX_ID', '数字カードボーナスサークル'],
#  ['INDEX_ID', '数字カード'],
#  ['INDEX_ID', '数字カード'],
#  ['INDEX_ID', '数字カード'],
#  ['INDEX_ID', '数字カード'],
#  ['INDEX_ID', '数字カード'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '実行委員会'],
#  ['INDEX_ID', '実行委員会'],
#  ['INDEX_ID', '実行委員会'],
#  ['INDEX_ID', '実行委員会'],
#  ['INDEX_ID', '実行委員会'],
#  ['INDEX_ID', '実行委員会'],
#  ['INDEX_ID', '実行委員会'],
#  ['INDEX_ID', '大会開催地'],
#  ['INDEX_ID', '同時に提出'],
#  ['INDEX_ID', '各種ゲート等'],
#  ['INDEX_ID', '参加チーム'],
#  ['INDEX_ID', '参加チーム'],
#  ['INDEX_ID', '参加チーム'],
#  ['INDEX_ID', '参加チーム'],
#  ['INDEX_ID', '参加チーム'],
#  ['INDEX_ID', '参加チーム'],
#  ['INDEX_ID', '参加チーム'],
#  ['INDEX_ID', '初期値情報'],
#  ['INDEX_ID', '全クラス共通'],
#  ['INDEX_ID', '全カラーブロック'],
#  ['INDEX_ID', '交点サークル'],
#  ['INDEX_ID', '交点サークル'],
#  ['INDEX_ID', '交点サークル'],
#  ['INDEX_ID', '交点サークル'],
#  ['INDEX_ID', '交点サークル'],
#  ['INDEX_ID', '交点サークル'],
#  ['INDEX_ID', '中間ゲート2'],
#  ['INDEX_ID', '中間ゲート1'],
#  ['INDEX_ID', '中間ゲート1'],
#  ['INDEX_ID', '中間ゲート'],
#  ['INDEX_ID', '中間ゲート'],
#  ['INDEX_ID', '一定期日前'],
#  ['INDEX_ID', 'リザルトタイム確定タッチセンサ押下操作後'],
#  ['INDEX_ID', 'リザルトタイム確定'],
#  ['INDEX_ID', 'リザルトタイム確定'],
#  ['INDEX_ID', 'リザルトタイム確定'],
#  ['INDEX_ID', 'リザルトタイム'],
#  ['INDEX_ID', 'リザルトタイム'],
#  ['INDEX_ID', 'リザルトタイム'],
#  ['INDEX_ID', 'リザルトタイム'],
#  ['INDEX_ID', 'リザルトタイム'],
#  ['INDEX_ID', 'リザルトタイム'],
#  ['INDEX_ID', 'ボーナスブロック'],
#  ['INDEX_ID', 'ボーナスタイム獲得例'],
#  ['INDEX_ID', 'ボーナスタイム獲得'],
#  ['INDEX_ID', 'ボーナスタイム'],
#  ['INDEX_ID', 'ボーナスタイム'],
#  ['INDEX_ID', 'ボーナスタイム'],
#  ['INDEX_ID', 'ボーナスタイム'],
#  ['INDEX_ID', 'ボーナスサークル設置'],
#  ['INDEX_ID', 'ボーナスサークル設置'],
#  ['INDEX_ID', 'ボーナスサークルブロックサークル番号'],
#  ['INDEX_ID', 'ボーナスサークル'],
#  ['INDEX_ID', 'ボーナスサークル'],
#  ['INDEX_ID', 'ボーナス'],
#  ['INDEX_ID', 'プラットフォーム改変制限'],
#  ['INDEX_ID', 'プラットフォーム改変'],
#  ['INDEX_ID', 'ブロック搬入'],
#  ['INDEX_ID', 'ブロックブロックビンゴ2020'],
#  ['INDEX_ID', 'ブロックビンゴ2020エリア上'],
#  ['INDEX_ID', 'ブロックビンゴ2020エリア'],
#  ['INDEX_ID', 'ブロックビンゴ2020'],
#  ['INDEX_ID', 'ブロックビンゴ2020'],
#  ['INDEX_ID', 'ブロックビンゴ2020'],
#  ['INDEX_ID', 'ブロックビンゴ2020'],
#  ['INDEX_ID', 'ブロックサークル番号8'],
#  ['INDEX_ID', 'ブロックサークル番号8'],
#  ['INDEX_ID', 'ブロックサークル番号6'],
#  ['INDEX_ID', 'ブロックサークル番号6'],
#  ['INDEX_ID', 'ブロックサークル番号3'],
#  ['INDEX_ID', 'ブロックサークル番号1'],
#  ['INDEX_ID', 'ブロックサークル番号'],
#  ['INDEX_ID', 'ブロックサークル内'],
#  ['INDEX_ID', 'ブロックサークル'],
#  ['INDEX_ID', 'ブロックサークル'],
#  ['INDEX_ID', 'ブロックサークル'],
#  ['INDEX_ID', 'ブロックサークル'],
#  ['INDEX_ID', 'ブロックサークル'],
#  ['INDEX_ID', 'ブロックサークル'],
#  ['INDEX_ID', 'ブロック'],
#  ['INDEX_ID', 'ブロック'],
#  ['INDEX_ID', 'ブロック'],
#  ['INDEX_ID', 'ブロック'],
#  ['INDEX_ID', 'ブロック'],
#  ['INDEX_ID', 'ブロック'],
#  ['INDEX_ID', 'ブロック'],
#  ['INDEX_ID', 'フォルダ以外'],
#  ['INDEX_ID', 'ナンバー黒ブロック全体'],
#  ['INDEX_ID', 'ナンバー黒ブロック'],
#  ['INDEX_ID', 'ナンバー黒ブロック'],
#  ['INDEX_ID', 'ナンバー黒ブロック'],
#  ['INDEX_ID', 'ナンバー黒ブロック'],
#  ['INDEX_ID', 'ナンバー黒ブロック'],
#  ['INDEX_ID', 'ナンバー黒ブロック'],
#  ['INDEX_ID', 'ナンバー黒ブロック'],
#  ['INDEX_ID', 'ナンバーボーナスサークル'],
#  ['INDEX_ID', 'ナンバーボーナスサークル'],
#  ['INDEX_ID', 'トリプルビンゴ'],
#  ['INDEX_ID', 'タッチセンサ押下操作後'],
#  ['INDEX_ID', 'タッチセンサ押下操作実行委員会'],
#  ['INDEX_ID', 'タッチセンサ押下操作'],
#  ['INDEX_ID', 'タッチセンサ押下操作'],
#  ['INDEX_ID', 'タイム'],
#  ['INDEX_ID', 'タイム'],
#  ['INDEX_ID', 'ソフトウェア'],
#  ['INDEX_ID', 'スポンサー看板'],
#  ['INDEX_ID', 'スタート準備走行'],
#  ['INDEX_ID', 'スタート準備'],
#  ['INDEX_ID', 'スタート成立後'],
#  ['INDEX_ID', 'スタート位置'],
#  ['INDEX_ID', 'スタートライン手前'],
#  ['INDEX_ID', 'スタートライン'],
#  ['INDEX_ID', 'スタートライン'],
#  ['INDEX_ID', 'スタートライン'],
#  ['INDEX_ID', 'スタートライン'],
#  ['INDEX_ID', 'スタートエリア'],
#  ['INDEX_ID', 'スタートエリア'],
#  ['INDEX_ID', 'スタートエリア'],
#  ['INDEX_ID', 'スタートエリア'],
#  ['INDEX_ID', 'スタート'],
#  ['INDEX_ID', 'シングルビンゴ'],
#  ['INDEX_ID', 'シミュレーション動作'],
#  ['INDEX_ID', 'コース'],
#  ['INDEX_ID', 'コース'],
#  ['INDEX_ID', 'コース'],
#  ['INDEX_ID', 'コース'],
#  ['INDEX_ID', 'コース'],
#  ['INDEX_ID', 'コース'],
#  ['INDEX_ID', 'ガレージ方向'],
#  ['INDEX_ID', 'カラーブロック有効移動'],
#  ['INDEX_ID', 'カラーブロック有効移動'],
#  ['INDEX_ID', 'カラーブロック全体'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーサークル'],
#  ['INDEX_ID', 'オレンジ範囲'],
#  ['INDEX_ID', 'アドバンストクラス難所'],
#  ['INDEX_ID', 'アドバンストクラス固有'],
#  ['INDEX_ID', 'アドバンストクラス'],
#  ['INDEX_ID', 'アドバンストクラス'],
#  ['INDEX_ID', 'アクティビティ'],
#  ['INDEX_ID', 'ほぼ左右対称'],
#  ['INDEX_ID', 'なお走行タイム'],
#  ['INDEX_ID', 'それぞれ個別'],
#  ['INDEX_ID', 'そのソフトウェア'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'この順に通過'],
#  ['INDEX_ID', 'および構成要素'],
#  ['INDEX_ID', 'および数字カード'],
#  ['INDEX_ID', 'および提出方法'],
#  ['INDEX_ID', 'および中間ゲート2'],
#  ['INDEX_ID', 'およびゴールゲート'],
#  ['INDEX_ID', 'い'],
#  ['INDEX_ID', 'timescale１'],
#  ['INDEX_ID', 'framespersecond'],
#  ['INDEX_ID', 'etロボコンキャラクターロゴ'],
#  ['INDEX_ID', 'etロボコンev3サポートサイト'],
#  ['INDEX_ID', 'etロボコン2020ロゴ'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ内'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ上'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ'],
#  ['INDEX_ID', 'etソフトウェアデザインロボットコンテスト2020シミュレータ競技規約1'],
#  ['INDEX_ID', 'etソフトウェアデザインロボットコンテスト2020シミュレータ競技規約1'],
#  ['INDEX_ID', 'etソフトウェアデザインロボットコンテスト2020シミュレータ競技規約1'],
#  ['INDEX_ID', 'etソフトウェアデザインロボットコンテスト2020シミュレータ競技'],
#  ['INDEX_ID', 'etrobo開発環境'],
#  ['INDEX_ID', '6'],
#  ['INDEX_ID', '6'],
#  ['INDEX_ID', '6'],
#  ['INDEX_ID', '6'],
#  ['INDEX_ID', '6'],
#  ['INDEX_ID', '6'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '1チーム当たりlコース'],
#  ['INDEX_ID', '120秒経過後'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '0'],
#  ['INDEX_ID', '0'],
#  ['INDEX_ID', '0']]

# %%
#重複の削除およびソート
def get_unique_list(seq):
    seen = []
    return [x for x in seq if x not in seen and not seen.append(x)]

# %%
classifier_list.sort()
classifier_list=get_unique_list(classifier_list)
#重複の削除およびソート

classifier_list
# Out:
# [['INDEX_ID', '0'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '120秒経過後'],
#  ['INDEX_ID', '1チーム当たりlコース'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '6'],
#  ['INDEX_ID', 'etrobo開発環境'],
#  ['INDEX_ID', 'etソフトウェアデザインロボットコンテスト2020シミュレータ競技'],
#  ['INDEX_ID', 'etソフトウェアデザインロボットコンテスト2020シミュレータ競技規約1'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ上'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ内'],
#  ['INDEX_ID', 'etロボコン2020ロゴ'],
#  ['INDEX_ID', 'etロボコンev3サポートサイト'],
#  ['INDEX_ID', 'etロボコンキャラクターロゴ'],
#  ['INDEX_ID', 'framespersecond'],
#  ['INDEX_ID', 'timescale１'],
#  ['INDEX_ID', 'い'],
#  ['INDEX_ID', 'およびゴールゲート'],
#  ['INDEX_ID', 'および中間ゲート2'],
#  ['INDEX_ID', 'および提出方法'],
#  ['INDEX_ID', 'および数字カード'],
#  ['INDEX_ID', 'および構成要素'],
#  ['INDEX_ID', 'この順に通過'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'そのソフトウェア'],
#  ['INDEX_ID', 'それぞれ個別'],
#  ['INDEX_ID', 'なお走行タイム'],
#  ['INDEX_ID', 'ほぼ左右対称'],
#  ['INDEX_ID', 'アクティビティ'],
#  ['INDEX_ID', 'アドバンストクラス'],
#  ['INDEX_ID', 'アドバンストクラス固有'],
#  ['INDEX_ID', 'アドバンストクラス難所'],
#  ['INDEX_ID', 'オレンジ範囲'],
#  ['INDEX_ID', 'カラーサークル'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック全体'],
#  ['INDEX_ID', 'カラーブロック有効移動'],
#  ['INDEX_ID', 'ガレージ方向'],
#  ['INDEX_ID', 'コース'],
#  ['INDEX_ID', 'シミュレーション動作'],
#  ['INDEX_ID', 'シングルビンゴ'],
#  ['INDEX_ID', 'スタート'],
#  ['INDEX_ID', 'スタートエリア'],
#  ['INDEX_ID', 'スタートライン'],
#  ['INDEX_ID', 'スタートライン手前'],
#  ['INDEX_ID', 'スタート位置'],
#  ['INDEX_ID', 'スタート成立後'],
#  ['INDEX_ID', 'スタート準備'],
#  ['INDEX_ID', 'スタート準備走行'],
#  ['INDEX_ID', 'スポンサー看板'],
#  ['INDEX_ID', 'ソフトウェア'],
#  ['INDEX_ID', 'タイム'],
#  ['INDEX_ID', 'タッチセンサ押下操作'],
#  ['INDEX_ID', 'タッチセンサ押下操作実行委員会'],
#  ['INDEX_ID', 'タッチセンサ押下操作後'],
#  ['INDEX_ID', 'トリプルビンゴ'],
#  ['INDEX_ID', 'ナンバーボーナスサークル'],
#  ['INDEX_ID', 'ナンバー黒ブロック'],
#  ['INDEX_ID', 'ナンバー黒ブロック全体'],
#  ['INDEX_ID', 'フォルダ以外'],
#  ['INDEX_ID', 'ブロック'],
#  ['INDEX_ID', 'ブロックサークル'],
#  ['INDEX_ID', 'ブロックサークル内'],
#  ['INDEX_ID', 'ブロックサークル番号'],
#  ['INDEX_ID', 'ブロックサークル番号1'],
#  ['INDEX_ID', 'ブロックサークル番号3'],
#  ['INDEX_ID', 'ブロックサークル番号6'],
#  ['INDEX_ID', 'ブロックサークル番号8'],
#  ['INDEX_ID', 'ブロックビンゴ2020'],
#  ['INDEX_ID', 'ブロックビンゴ2020エリア'],
#  ['INDEX_ID', 'ブロックビンゴ2020エリア上'],
#  ['INDEX_ID', 'ブロックブロックビンゴ2020'],
#  ['INDEX_ID', 'ブロック搬入'],
#  ['INDEX_ID', 'プラットフォーム改変'],
#  ['INDEX_ID', 'プラットフォーム改変制限'],
#  ['INDEX_ID', 'ボーナス'],
#  ['INDEX_ID', 'ボーナスサークル'],
#  ['INDEX_ID', 'ボーナスサークルブロックサークル番号'],
#  ['INDEX_ID', 'ボーナスサークル設置'],
#  ['INDEX_ID', 'ボーナスタイム'],
#  ['INDEX_ID', 'ボーナスタイム獲得'],
#  ['INDEX_ID', 'ボーナスタイム獲得例'],
#  ['INDEX_ID', 'ボーナスブロック'],
#  ['INDEX_ID', 'リザルトタイム'],
#  ['INDEX_ID', 'リザルトタイム確定'],
#  ['INDEX_ID', 'リザルトタイム確定タッチセンサ押下操作後'],
#  ['INDEX_ID', '一定期日前'],
#  ['INDEX_ID', '中間ゲート'],
#  ['INDEX_ID', '中間ゲート1'],
#  ['INDEX_ID', '中間ゲート2'],
#  ['INDEX_ID', '交点サークル'],
#  ['INDEX_ID', '全カラーブロック'],
#  ['INDEX_ID', '全クラス共通'],
#  ['INDEX_ID', '初期値情報'],
#  ['INDEX_ID', '参加チーム'],
#  ['INDEX_ID', '各種ゲート等'],
#  ['INDEX_ID', '同時に提出'],
#  ['INDEX_ID', '大会開催地'],
#  ['INDEX_ID', '実行委員会'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字カード'],
#  ['INDEX_ID', '数字カードボーナスサークル'],
#  ['INDEX_ID', '数字カード置き場'],
#  ['INDEX_ID', '数字カード黒ブロック'],
#  ['INDEX_ID', '数字カード黒ブロック全体'],
#  ['INDEX_ID', '時間計測'],
#  ['INDEX_ID', '最大計測時間'],
#  ['INDEX_ID', '灰色点線内'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '計測終了操作'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置プライマリークラス難所'],
#  ['INDEX_ID', '走行'],
#  ['INDEX_ID', '走行タイム'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体ソフトウェア'],
#  ['INDEX_ID', '走行体全体'],
#  ['INDEX_ID', '進入以降具体的'],
#  ['INDEX_ID', '関連ファイル'],
#  ['INDEX_ID', '黒'],
#  ['INDEX_ID', '黒ブロック']]

# %%
dic = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/dic.csv")

# %%
counter_suffix=['位','宇','折','果','箇','荷','菓','掛','顆','回','階','画','頭','方','株','巻','管','缶','基','機','騎','切','客','脚','行','局','句','軀','口','具','組','景','桁','件','軒','個','戸','号','合','梱','献','喉','座','棹','冊','皿','氏','締','字','軸','室','首','重','床','条','畳','錠','帖','筋','食','隻','膳','双','艘','足','揃','体','袋','台','題','立','卓','束','玉','着','丁','挺','帳','張','つ','対','通','番','粒','艇','滴','点','度','等','堂','人','把','羽','張','刎','杯','柱','鉢','発','尾','匹','瓶','振','部','幅','服','房','篇','遍','本','間','枚','前','幕','棟','名','面','門','問','山','葉','流','旒','両','領','輪','連','椀','碗']
v_list=[]

value=""
for x in docs1:
  for y in x.split():
    if (any(map(str.isdigit, y))):#数字を含む文章かどうか
        for num in y:
          if num.isdigit() or num==".":
            value=value+num
        for z in counter_suffix:
          if not len(y)==y.find(value)+len(value):
            if z in y[y.find(value)+len(value)]:#文章中に単位があるか
              for d in dic.values:
                if not (d[2] is np.nan):
                  if z in d[2]:
                    for y2 in x.split():#単位がある文にその単位を使う名詞があるか
     
                      if d[1] in y2 and not y2[len(y2)-1].isdigit() and not y==y2:
                        list_=[]
                        list_.append("INDEX_ID")
                        list_.append(y2)
                        list_.append(value)
                        v_list.append(list_)
    value=""
# Out:
# [['INDEX_ID', '5種類', '2'],
#  ['INDEX_ID', 'ブロック', '8'],
#  ['INDEX_ID', 'カラーブロック', '8'],
#  ['INDEX_ID', 'ブロック', '10'],
#  ['INDEX_ID', 'カラーブロック', '10'],
#  ['INDEX_ID', 'ナンバー黒ブロック', '10'],
#  ['INDEX_ID', '数字カード黒ブロック', '10'],
#  ['INDEX_ID', '黒ブロック', '10'],
#  ['INDEX_ID', 'ブロック', '10'],
#  ['INDEX_ID', 'カラーブロック', '6'],
#  ['INDEX_ID', '数字カード黒ブロック', '6']]

# %%
d_list=[]
for x in v_list:
  for count_w, y in enumerate(wlist1):
    if y == x[1]:#定数名の単語を探す
      for p,z in enumerate(TF_list):
        if z[count_w]>0:#定数名のTF_IDF値を持つ文を抽出
          sentence_list=[]
          for count_TF,l in enumerate(z):
            if l>0:
              sentence_list.append(wlist1[count_TF])
            lists_=[]
            lists_.append(x[1])
            lists_.append(x[2])
            lists_.append(z[count_w])
            for m in sentence_list:
              for d in counter_suffix:  
                if x[2] in m and d in m:
                  d_list.append(lists_)

# %%
d_list=get_unique_list(d_list)
d_list.sort()
d_list
# Out:
# [['5種類', '2', 0.3143737437910255],
#  ['カラーブロック', '10', 0.2013388075934368],
#  ['カラーブロック', '6', 0.18958645482638511],
#  ['カラーブロック', '8', 0.18958645482638511],
#  ['カラーブロック', '8', 0.2938267938325111],
#  ['ナンバー黒ブロック', '10', 0.21402443873625698],
#  ['ブロック', '10', 0.42804887747251397],
#  ['ブロック', '8', 0.31233975897315797],
#  ['数字カード黒ブロック', '10', 0.24074397708402967],
#  ['数字カード黒ブロック', '6', 0.2266915041452421],
#  ['黒ブロック', '10', 0.24074397708402967]]

# %%
f_list=[]
tmp=["",0,0]
for x in d_list:
  if tmp[0]=="" or not tmp[0]==x[0]:
    f_list.append(tmp)
    tmp=x
  if tmp[2]<x[2]:
    tmp=x
f_list.append(tmp)  
f_list.pop(0)
f_list
# Out:
# [['5種類', '2', 0.3143737437910255],
#  ['カラーブロック', '8', 0.2938267938325111],
#  ['ナンバー黒ブロック', '10', 0.21402443873625698],
#  ['ブロック', '10', 0.42804887747251397],
#  ['数字カード黒ブロック', '10', 0.24074397708402967],
#  ['黒ブロック', '10', 0.24074397708402967]]

# %%
for x in f_list:
  list_=[]
  list_.append("INDEX_ID") 
  list_.append(x[0])
  list_.append(x[1])
  classifier_list.append(list_)

classifier_list
# Out:
# [['INDEX_ID', '0'],
#  ['INDEX_ID', '1'],
#  ['INDEX_ID', '120秒経過後'],
#  ['INDEX_ID', '1チーム当たりlコース'],
#  ['INDEX_ID', '2'],
#  ['INDEX_ID', '3'],
#  ['INDEX_ID', '6'],
#  ['INDEX_ID', 'etrobo開発環境'],
#  ['INDEX_ID', 'etソフトウェアデザインロボットコンテスト2020シミュレータ競技'],
#  ['INDEX_ID', 'etソフトウェアデザインロボットコンテスト2020シミュレータ競技規約1'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ上'],
#  ['INDEX_ID', 'etロボコン2020シミュレータ内'],
#  ['INDEX_ID', 'etロボコン2020ロゴ'],
#  ['INDEX_ID', 'etロボコンev3サポートサイト'],
#  ['INDEX_ID', 'etロボコンキャラクターロゴ'],
#  ['INDEX_ID', 'framespersecond'],
#  ['INDEX_ID', 'timescale１'],
#  ['INDEX_ID', 'い'],
#  ['INDEX_ID', 'およびゴールゲート'],
#  ['INDEX_ID', 'および中間ゲート2'],
#  ['INDEX_ID', 'および提出方法'],
#  ['INDEX_ID', 'および数字カード'],
#  ['INDEX_ID', 'および構成要素'],
#  ['INDEX_ID', 'この順に通過'],
#  ['INDEX_ID', 'され'],
#  ['INDEX_ID', 'される'],
#  ['INDEX_ID', 'し'],
#  ['INDEX_ID', 'する'],
#  ['INDEX_ID', 'そのソフトウェア'],
#  ['INDEX_ID', 'それぞれ個別'],
#  ['INDEX_ID', 'なお走行タイム'],
#  ['INDEX_ID', 'ほぼ左右対称'],
#  ['INDEX_ID', 'アクティビティ'],
#  ['INDEX_ID', 'アドバンストクラス'],
#  ['INDEX_ID', 'アドバンストクラス固有'],
#  ['INDEX_ID', 'アドバンストクラス難所'],
#  ['INDEX_ID', 'オレンジ範囲'],
#  ['INDEX_ID', 'カラーサークル'],
#  ['INDEX_ID', 'カラーブロック'],
#  ['INDEX_ID', 'カラーブロック全体'],
#  ['INDEX_ID', 'カラーブロック有効移動'],
#  ['INDEX_ID', 'ガレージ方向'],
#  ['INDEX_ID', 'コース'],
#  ['INDEX_ID', 'シミュレーション動作'],
#  ['INDEX_ID', 'シングルビンゴ'],
#  ['INDEX_ID', 'スタート'],
#  ['INDEX_ID', 'スタートエリア'],
#  ['INDEX_ID', 'スタートライン'],
#  ['INDEX_ID', 'スタートライン手前'],
#  ['INDEX_ID', 'スタート位置'],
#  ['INDEX_ID', 'スタート成立後'],
#  ['INDEX_ID', 'スタート準備'],
#  ['INDEX_ID', 'スタート準備走行'],
#  ['INDEX_ID', 'スポンサー看板'],
#  ['INDEX_ID', 'ソフトウェア'],
#  ['INDEX_ID', 'タイム'],
#  ['INDEX_ID', 'タッチセンサ押下操作'],
#  ['INDEX_ID', 'タッチセンサ押下操作実行委員会'],
#  ['INDEX_ID', 'タッチセンサ押下操作後'],
#  ['INDEX_ID', 'トリプルビンゴ'],
#  ['INDEX_ID', 'ナンバーボーナスサークル'],
#  ['INDEX_ID', 'ナンバー黒ブロック'],
#  ['INDEX_ID', 'ナンバー黒ブロック全体'],
#  ['INDEX_ID', 'フォルダ以外'],
#  ['INDEX_ID', 'ブロック'],
#  ['INDEX_ID', 'ブロックサークル'],
#  ['INDEX_ID', 'ブロックサークル内'],
#  ['INDEX_ID', 'ブロックサークル番号'],
#  ['INDEX_ID', 'ブロックサークル番号1'],
#  ['INDEX_ID', 'ブロックサークル番号3'],
#  ['INDEX_ID', 'ブロックサークル番号6'],
#  ['INDEX_ID', 'ブロックサークル番号8'],
#  ['INDEX_ID', 'ブロックビンゴ2020'],
#  ['INDEX_ID', 'ブロックビンゴ2020エリア'],
#  ['INDEX_ID', 'ブロックビンゴ2020エリア上'],
#  ['INDEX_ID', 'ブロックブロックビンゴ2020'],
#  ['INDEX_ID', 'ブロック搬入'],
#  ['INDEX_ID', 'プラットフォーム改変'],
#  ['INDEX_ID', 'プラットフォーム改変制限'],
#  ['INDEX_ID', 'ボーナス'],
#  ['INDEX_ID', 'ボーナスサークル'],
#  ['INDEX_ID', 'ボーナスサークルブロックサークル番号'],
#  ['INDEX_ID', 'ボーナスサークル設置'],
#  ['INDEX_ID', 'ボーナスタイム'],
#  ['INDEX_ID', 'ボーナスタイム獲得'],
#  ['INDEX_ID', 'ボーナスタイム獲得例'],
#  ['INDEX_ID', 'ボーナスブロック'],
#  ['INDEX_ID', 'リザルトタイム'],
#  ['INDEX_ID', 'リザルトタイム確定'],
#  ['INDEX_ID', 'リザルトタイム確定タッチセンサ押下操作後'],
#  ['INDEX_ID', '一定期日前'],
#  ['INDEX_ID', '中間ゲート'],
#  ['INDEX_ID', '中間ゲート1'],
#  ['INDEX_ID', '中間ゲート2'],
#  ['INDEX_ID', '交点サークル'],
#  ['INDEX_ID', '全カラーブロック'],
#  ['INDEX_ID', '全クラス共通'],
#  ['INDEX_ID', '初期値情報'],
#  ['INDEX_ID', '参加チーム'],
#  ['INDEX_ID', '各種ゲート等'],
#  ['INDEX_ID', '同時に提出'],
#  ['INDEX_ID', '大会開催地'],
#  ['INDEX_ID', '実行委員会'],
#  ['INDEX_ID', '数字'],
#  ['INDEX_ID', '数字カード'],
#  ['INDEX_ID', '数字カードボーナスサークル'],
#  ['INDEX_ID', '数字カード置き場'],
#  ['INDEX_ID', '数字カード黒ブロック'],
#  ['INDEX_ID', '数字カード黒ブロック全体'],
#  ['INDEX_ID', '時間計測'],
#  ['INDEX_ID', '最大計測時間'],
#  ['INDEX_ID', '灰色点線内'],
#  ['INDEX_ID', '示す'],
#  ['INDEX_ID', '競技'],
#  ['INDEX_ID', '競技環境'],
#  ['INDEX_ID', '計測終了操作'],
#  ['INDEX_ID', '設置'],
#  ['INDEX_ID', '設置プライマリークラス難所'],
#  ['INDEX_ID', '走行'],
#  ['INDEX_ID', '走行タイム'],
#  ['INDEX_ID', '走行体'],
#  ['INDEX_ID', '走行体ソフトウェア'],
#  ['INDEX_ID', '走行体全体'],
#  ['INDEX_ID', '進入以降具体的'],
#  ['INDEX_ID', '関連ファイル'],
#  ['INDEX_ID', '黒'],
#  ['INDEX_ID', '黒ブロック'],
#  ['INDEX_ID', '5種類', '2'],
#  ['INDEX_ID', 'カラーブロック', '8'],
#  ['INDEX_ID', 'ナンバー黒ブロック', '10'],
#  ['INDEX_ID', 'ブロック', '10'],
#  ['INDEX_ID', '数字カード黒ブロック', '10'],
#  ['INDEX_ID', '黒ブロック', '10']]

# %%
new_list = sorted(classifier_list,reverse=True)
with open("/content/gdrive/My Drive/Colab Notebooks/classifier_list.csv", 'w') as f:
    writer = csv.writer(f, lineterminator='\n')
    for x in new_list:
        writer.writerow(x)

#抽出リストの出力
